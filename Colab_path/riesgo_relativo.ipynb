# %% [markdown]
# <a href="https://colab.research.google.com/github/Karenfonseca22/riesgo_relativo/blob/main/Colab_path/riesgo_relativo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # !pip install google-auth google-auth-oauthlib google-auth-httplib2 google-api-python-client pandas-gbq

# %%
from google.colab import auth
auth.authenticate_user()

# %%
# Reemplaza con tu ID de proyecto y el nombre de la tabla
project_id = 'riesgo-relativo-429614'  # Asegúrate de que este sea tu ID de proyecto real
dataset_id = 'Dataset'  # Nombre del conjunto de datos
table_id = 'user_info'  # Nombre de la tabla

# Consulta SQL para seleccionar los datos de la tabla
query = f'SELECT * FROM `{project_id}.{dataset_id}.{table_id}`'  # Corrección en la construcción de la consulta

# %%
# Import the pandas library
import pandas as pd
# Leer la tabla usando pandas_gbq
df = pd.read_gbq(query, project_id = project_id)

# Mostrar las primeras filas del DataFrame
df.head(10)
# Out:
#    user_id  age sex  last_month_salary  number_dependents
# 0     8870   21   F                NaN               <NA>
# 1    18876   21   F                NaN               <NA>
# 2    24483   21   M                NaN               <NA>
# 3    28075   21   M                NaN               <NA>
# 4    28122   21   M                NaN               <NA>
# 5    33474   21   M                NaN               <NA>
# 6     3319   22   F                NaN               <NA>
# 7    12771   22   M                NaN               <NA>
# 8    35417   22   M                NaN               <NA>
# 9     2308   23   M                NaN               <NA>

# %%
# Import the pandas library
import pandas as pd
# Leer la tabla usando pandas_gbq
df = pd.read_gbq(query, project_id = project_id)

# %%
# Grafico Boxplot
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(10, 6))
# Access the 'age' column of the DataFrame correctly
plt.boxplot(df['age'], patch_artist=True, notch=True)
plt.title('Boxplot de Variable de Interés vs Edad')
plt.xlabel('Edad')
plt.ylabel('age')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
# Access the 'age' column of the DataFrame correctly
plt.boxplot(df['last_month_salary'], patch_artist=True, notch=True)
plt.title('Last month salary Boxplot')
plt.xlabel('salary')
plt.ylabel('amount')
plt.grid(True)
plt.show()

# %%
# Creación de histogramas

import matplotlib.pyplot as plt

# variable elegida
data = df['last_month_salary']

# Crear el histograma
plt.hist(data, bins=10, edgecolor='red')

# Añadir títulos y etiquetas
plt.title('Histograma de last month salary')
plt.xlabel('Valores')
plt.ylabel('Frecuencia')

# Mostrar el histograma
plt.show()

# %%
from google.colab import auth
auth.authenticate_user()

# %%
import pandas as pd
## IMPORTAR UNA NUEVA TABLA DESDE BIGQUERY

# Reemplaza con tu ID de proyecto y el nombre de la nueva tabla
project_id = 'riesgo-relativo-429614'  # Asegúrate de que este sea tu ID de proyecto real
dataset_id = 'Dataset'  # Nombre del conjunto de datos
new_table_id = 'loans_detalle'  # Nombre de la nueva tabla

# Consulta SQL para seleccionar los datos de la nueva tabla
new_query = f'SELECT * FROM `{project_id}.{dataset_id}.{new_table_id}`'

# Cargar los datos de la nueva tabla en un nuevo DataFrame
new_df = pd.read_gbq(new_query, project_id=project_id)

# Ahora new_df contiene los datos de la nueva tabla en un DataFrame

# %%
new_df.head(10)
# Out:
#    user_id  more_90_days_overdue  using_lines_not_secured_personal_assets  \
# 0        1                     0                                 0.667083
# 1        2                     0                                 0.007093
# 2        3                     0                                 0.091213
# 3        4                     0                                 0.112680
# 4        5                     0                                 0.323985
# 5        6                     0                                 0.007300
# 6        8                     1                                 0.062280
# 7       10                     0                                 0.040263
# 8       12                     0                                 0.012198
# 9       13                     0                                 0.001346
#
#    number_times_delayed_payment_loan_30_59_days  debt_ratio  \
# 0                                             0    0.153112
# ...

# %%
plt.figure(figsize=(6, 6))
# Access the 'age' column of the DataFrame correctly
plt.boxplot(new_df['more_90_days_overdue'], patch_artist=True, notch=True)
plt.title('Boxplot 90 y + dias de retraso')
plt.xlabel('dias')
plt.ylabel('cantidad')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(3, 3))
# Access the 'age' column of the DataFrame correctly
plt.boxplot(new_df['using_lines_not_secured_personal_assets'], patch_artist=True, notch=True)
plt.title('Lineas no seguras con bienes personales')
plt.xlabel('dias')
plt.ylabel('cantidad')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(3, 3))
# Access the 'age' column of the DataFrame correctly
plt.boxplot(new_df['debt_ratio'], patch_artist=True, notch=True)
plt.title('Radio deuda')
plt.xlabel('radio deuda')
plt.ylabel('cantidad')
plt.grid(True)
plt.show()

# %%
import pandas as pd
## IMPORTAR UNA NUEVA TABLA DESDE BIGQUERY

# Reemplaza con tu ID de proyecto y el nombre de la nueva tabla
project_id = 'riesgo-relativo-429614'  # Asegúrate de que este sea tu ID de proyecto real
dataset_id = 'Dataset'  # Nombre del conjunto de datos
new_table_id = 'user_info_flag'  # Nombre de la nueva tabla

# Define the table ID to be used in the query
flag_table_id = new_table_id # Assign the value of new_table_id to flag_table_id

# Consulta SQL para seleccionar los datos de la nueva tabla
flag_query = f'SELECT * FROM `{project_id}.{dataset_id}.{flag_table_id}`'

# Cargar los datos de la nueva tabla en un nuevo DataFrame
flag_df = pd.read_gbq(flag_query, project_id=project_id) # Make sure to read the data into a Pandas DataFrame

# Now flag_df contains the data from the new table in a DataFrame
flag_df.head(10) # This should now work as flag_df is a Pandas DataFrame
# Out:
#    user_id  age sex  last_month_salary  number_dependents  default_flag  \
# 0     8870   21   F                NaN               <NA>             0
# 1    18876   21   F                NaN               <NA>             0
# 2    24483   21   M                NaN               <NA>             0
# 3    28075   21   M                NaN               <NA>             0
# 4    28122   21   M                NaN               <NA>             0
# 5    33474   21   M                NaN               <NA>             0
# 6     3319   22   F                NaN               <NA>             0
# 7    12771   22   M                NaN               <NA>             0
# 8    35417   22   M                NaN               <NA>             0
# 9     2308   23   M                NaN               <NA>             0
#
#      generacion
# 0  Generación Z
# 1  Generación Z
# 2  Generación Z
# 3  Generación Z
# 4  Generación Z
# 5  Generación Z
# 6  Generación Z
# 7  Generación Z
# 8  Generación Z
# ...

# %%
#HISTOGRAMA PARA VER DISTRIBUCION
import matplotlib.pyplot as plt

# Filtrar los datos donde default_flag es igual a 1
# Use 'flag_df' instead of 'df'
filtered_data = flag_df[flag_df['default_flag'] == 1]['last_month_salary']

# Crear el histograma
plt.hist(filtered_data, bins=10, edgecolor='red')

# Añadir títulos y etiquetas
plt.title('Histograma de last month salary (default_flag = 1)')
plt.xlabel('Valores')
plt.ylabel('Frecuencia')

# Mostrar el histograma
plt.show()

# %%
import scipy.stats as stats # Import the stats module

#Prueba de Shapiro Wilk
# Use 'flag_df' instead of 'df' for consistency
flag_df = df['last_month_salary'].values
stat, p_value = stats.shapiro(flag_df) # Use flag_df as input to shapiro function
print("Estadístico de Shapiro-Wilk:", stat)
print("Valor p:", p_value)
alpha = 0.05
# Out:
# Estadístico de Shapiro-Wilk: nan
# Valor p: nan

# %%
#HISTOGRAMA PARA VER DISTRIBUCIÓN
import matplotlib.pyplot as plt

# Filtrar los datos donde default_flag es igual a 0
# Use 'flag_df' instead of 'df'
filtered_data = flag_df[flag_df['default_flag'] == 0]['last_month_salary']

# Crear el histograma
plt.hist(filtered_data, bins=10, edgecolor='red')

# Añadir títulos y etiquetas
plt.title('Histograma de last month salary (default_flag = 0)')
plt.xlabel('Valores')
plt.ylabel('Frecuencia')

# Mostrar el histograma
plt.show()

# %%
import pandas as pd
## IMPORTAR UNA NUEVA TABLA DESDE BIGQUERY

# Reemplaza con tu ID de proyecto y el nombre de la nueva tabla
project_id = 'riesgo-relativo-429614'  # Asegúrate de que este sea tu ID de proyecto real
dataset_id = 'Dataset'  # Nombre del conjunto de datos
new_table_id = 'tabla_general'  # Nombre de la nueva tabla

# Define the table ID to be used in the query
general_table_id = new_table_id # Assign the value of new_table_id to flag_table_id

# Consulta SQL para seleccionar los datos de la nueva tabla
general_query = f'SELECT * FROM `{project_id}.{dataset_id}.{general_table_id}`'

# Cargar los datos de la nueva tabla en un nuevo DataFrame
general_df = pd.read_gbq(general_query, project_id=project_id)

# Ahora new_df contiene los datos de la nueva tabla en un DataFrame

# %%
general_df.head(10)
# Out:
#    user_id  age mayu_sex  number_dependents  default_flag    generacion  \
# 0     8870   21        F               <NA>             0  Generación Z
# 1    18876   21        F               <NA>             0  Generación Z
# 2    28075   21        M               <NA>             0  Generación Z
# 3    28122   21        M               <NA>             0  Generación Z
# 4    33474   21        M               <NA>             0  Generación Z
# 5     3319   22        F               <NA>             0  Generación Z
# 6    35417   22        M               <NA>             0  Generación Z
# 7     2308   23        M               <NA>             0  Generación Z
# 8     2757   23        M               <NA>             0  Generación Z
# 9    15497   23        M               <NA>             0  Generación Z
#
#   outlier_last_month_salary  last_month_salary_imputado  more_90_days_overdue  \
# 0               not_outlier                      5400.0                     0
# ...

# %% [markdown]
# **Histograma y scatter plot con la tabla general**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Handle missing values (replace NaNs with 0 for demonstration)
# You might want to explore other imputation methods depending on your data
general_df.fillna({'total_real_estate_loans': 0, 'total_other_loans': 0}, inplace=True)

# Extraer los datos para el gráfico
x = general_df['total_real_estate_loans']  # Datos para el eje X
y = general_df['total_other_loans']  # Datos para el eje Y

# Configuración de color y tamaño
colors = 'blue'  # Color para todos los puntos
area = (20 * np.random.rand(len(x)))**1  # Tamaño de cada punto

# Crear el gráfico de dispersión
plt.scatter(x, y, s=area, c=colors, alpha=0.5)

# Añadir etiquetas y título
plt.xlabel('Total Real Estate Loans') # Adjusted label to match data
plt.ylabel('Total Other Loans') # Adjusted label to match data
plt.title('Gráfico de Dispersión')

# Mostrar el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generar datos de ejemplo
general_data = ['debt_ratio']

# Crear el histograma
plt.figure(figsize=(6, 6))
plt.hist(data, bins=30, edgecolor='black', alpha=0.7)

# Añadir etiquetas y título
plt.title('debt_ratio')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')

# Mostrar el histograma
plt.grid(True)
plt.show()
